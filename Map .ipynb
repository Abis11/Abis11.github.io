# %%
#Import Modules
import osmnx as ox

# Specify the name of the City
place_name = "Bangor, GB"

# Fetch OSM street network from the location
graph = ox.graph_from_place(place_name, network_type  = "drive")

# %%
# Check data type of the graph
type(graph)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
# Plot the streets
ox.plot_graph(graph)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
area = ox.geocode_to_gdf(place_name,)

# %%
ox.footprints_from_place(place_name, )
# Out:
# <AxesSubplot:>

# %%
#Selecting amenities and extracting information
tags = {"amenity":"restaurant"}
food = ox.geometries_from_place(place_name, tags=tags)
